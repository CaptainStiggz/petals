# %%
import matplotlib.pyplot as plt
from petal_process_v1 import PetalProcessor
import cv2
import image_utils as itools
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
img = itools.read_file("../dataset/Petals Test/1B/ST1_SE010262.jpg")
plt.imshow(img)

# %%
processor = PetalProcessor("../dataset/Petals (Cropped)/")

# %%
processor.deduplicate()

# %%
processor.crop_all_to_largest_square()

# %%
processor.resize_all()
# Out:
# Processing 99606 files...
# Progress: [>                   ] 5 %
# Progress: [>                   ] 7 %
# Progress: [>                   ] 8 %
# IMG TOO SMALL--->              ] 34 %
# Found empty: ../dataset/Petals (Cropped)/Petals 7/7H/ST07_SE084293.jpg. Deleting...
# Progress: [------------------------->] 132 %
